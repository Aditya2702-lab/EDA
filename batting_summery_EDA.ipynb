# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('batting_summary.csv')

# %%
df
# Out:
#      Match_no           Match_Between Team_Innings        Batsman_Name  \
# 0           1  England vs New Zealand      England      Jonny Bairstow
# 1           1  England vs New Zealand      England         Dawid Malan
# 2           1  England vs New Zealand      England            Joe Root
# 3           1  England vs New Zealand      England         Harry Brook
# 4           1  England vs New Zealand      England           Moeen Ali
# ..        ...                     ...          ...                 ...
# 911        48      India vs Australia    Australia         Travis Head
# 912        48      India vs Australia    Australia      Mitchell Marsh
# 913        48      India vs Australia    Australia         Steve Smith
# 914        48      India vs Australia    Australia  Marnus Labuschagne
# 915        48      India vs Australia    Australia       Glenn Maxwell
#
#      Batting_Position                            Dismissal  Runs  Balls  4s  \
# ...

# %%
df.isnull().sum()
# Out:
# Match_no            0
# Match_Between       0
# Team_Innings        0
# Batsman_Name        0
# Batting_Position    0
# Dismissal           2
# Runs                0
# Balls               0
# 4s                  0
# 6s                  0
# Strike_Rate         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 916 entries, 0 to 915
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Match_no          916 non-null    int64
#  1   Match_Between     916 non-null    object
#  2   Team_Innings      916 non-null    object
#  3   Batsman_Name      916 non-null    object
#  4   Batting_Position  916 non-null    int64
#  5   Dismissal         914 non-null    object
#  6   Runs              916 non-null    int64
#  7   Balls             916 non-null    int64
#  8   4s                916 non-null    int64
#  9   6s                916 non-null    int64
#  10  Strike_Rate       916 non-null    object
# dtypes: int64(6), object(5)
# memory usage: 78.8+ KB

# %%
df.describe()
# Out:
#          Match_no  Batting_Position        Runs       Balls          4s  \
# count  916.000000        916.000000  916.000000  916.000000  916.000000
# mean    24.669214          5.398472   26.510917   29.021834    2.533843
# std     14.042355          3.035952   30.788666   28.493381    3.119120
# min      1.000000          1.000000    0.000000    0.000000    0.000000
# 25%     12.000000          3.000000    5.000000    8.000000    0.000000
# 50%     25.000000          5.000000   15.000000   19.000000    1.000000
# 75%     37.000000          8.000000   38.000000   40.250000    4.000000
# max     48.000000         11.000000  201.000000  143.000000   21.000000
#
#                6s
# count  916.000000
# mean     0.727074
# std      1.482049
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max     11.000000

# %%
df.columns
# Out:
# Index(['Match_no', 'Match_Between', 'Team_Innings', 'Batsman_Name',
#        'Batting_Position', 'Dismissal', 'Runs', 'Balls', '4s', '6s',
#        'Strike_Rate'],
#       dtype='object')

# %%
df.drop(labels=[ 'Match_Between', 'Team_Innings', 'Batsman_Name','Dismissal',],axis=1,inplace=True)

# %%
df
# Out:
#      Match_no  Batting_Position  Runs  Balls  4s  6s Strike_Rate
# 0           1                 1    33     35   4   1      94.300
# 1           1                 2    14     24   2   0      58.300
# 2           1                 3    77     86   4   1      89.500
# 3           1                 4    25     16   4   1     156.300
# 4           1                 5    11     17   1   0      64.700
# ..        ...               ...   ...    ...  ..  ..         ...
# 911        48                 2   137    120  15   4     114.167
# 912        48                 3    15     15   1   1     100.000
# 913        48                 4     4      9   1   0      44.444
# 914        48                 5    58    110   4   0      52.727
# 915        48                 6     2      1   0   0     200.000
#
# [916 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Match_no            0
# Batting_Position    0
# Runs                0
# Balls               0
# 4s                  0
# 6s                  0
# Strike_Rate         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Match_no', 'Batting_Position', 'Runs', 'Balls', '4s', '6s',
#        'Strike_Rate'],
#       dtype='object')

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['Batting_Position'],df['Runs'])
plt.xlabel('Batting_Position')
plt.ylabel('Runs')
plt.show()

# %%
def bar_plot(x_variable):
   
    varValue = df.groupby(x_variable)["Runs"].sum()  # Summing Runs for each category
    
    plt.figure(figsize=(9, 3))
    plt.bar(varValue.index, varValue)
    plt.xticks(varValue.index, varValue.index.values)
    plt.ylabel("Total Runs")
    plt.title(f"Total Runs by {x_variable}")
    plt.show()
    
    print(f"Total Runs grouped by {x_variable}: \n{varValue}")

# %%
df.columns
# Out:
# Index(['Match_no', 'Batting_Position', 'Runs', 'Balls', '4s', '6s',
#        'Strike_Rate'],
#       dtype='object')

# %%
col=['Batting_Position','Balls','4s','6s']
for i in col:
    bar_plot(i)
# Out:
# Total Runs grouped by Batting_Position:
# Batting_Position
# 1     3684
# 2     3407
# 3     4079
# 4     4048
# 5     2694
# 6     2322
# 7     1674
# 8      916
# 9      787
# 10     476
# 11     197
# Name: Runs, dtype: int64
# Total Runs grouped by Balls:
# Balls
# 0        0
# 1       21
# 2       36
# 3       73
# 4       72
#       ...
# 127    130
# 128    201
# 132    177
# 140    174
# 143    129
# Name: Runs, Length: 118, dtype: int64
# Total Runs grouped by 4s:
# 4s
# 0     1136
# 1     2271
# 2     2702
# 3     2767
# 4     2650
# 5     1421
# 6     2124
# 7     1590
# 8     1982
# 9     1461
# 10    1190
# 11     812
# 12     459
# 13     108
# 14     391
# 15     419
# 16     271
# 17     177
# 19     152
# 21     201
# Name: Runs, dtype: int64
# Total Runs grouped by 6s:
# 6s
# 0     8735
# 1     4844
# 2     3397
# 3     2196
# 4     1369
# 5     1472
# 6      608
# 7      498
# 8      377
# 9      461
# 10     201
# 11     126
# Name: Runs, dtype: int64

# %%
def plot_hist(column):
    
    plt.figure(figsize=(8, 6))
    plt.hist(df[column], bins=20, color="skyblue", edgecolor="black", alpha=0.7)
    plt.title(column)
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.show()

# %%
col=['Runs','Balls','Strike_Rate']
for i in col:
    plot_hist(i)

# %%
df.dtypes
# Out:
# Match_no             int64
# Batting_Position     int64
# Runs                 int64
# Balls                int64
# 4s                   int64
# 6s                   int64
# Strike_Rate         object
# dtype: object

# %%
df['Strike_Rate'] = pd.to_numeric(df['Strike_Rate'], errors='coerce')

# %%
df.dtypes
# Out:
# Match_no              int64
# Batting_Position      int64
# Runs                  int64
# Balls                 int64
# 4s                    int64
# 6s                    int64
# Strike_Rate         float64
# dtype: object

# %%
df.groupby('Batting_Position', as_index=False).mean().sort_values(by='Runs', ascending=False)
# Out:
#     Batting_Position   Match_no       Runs      Balls        4s        6s  \
# 3                  4  24.795918  41.306122  44.510204  3.683673  0.969388
# 2                  3  24.660000  40.790000  45.270000  3.910000  0.710000
# 0                  1  24.660000  36.840000  36.900000  4.200000  1.120000
# 1                  2  24.660000  34.070000  36.230000  3.880000  1.010000
# 4                  5  24.797872  28.659574  31.851064  2.414894  0.797872
# 5                  6  24.954545  26.386364  26.727273  2.261364  0.965909
# 6                  7  24.802469  20.666667  22.111111  1.530864  0.753086
# 7                  8  24.520548  12.547945  17.260274  1.027397  0.287671
# 8                  9  24.579710  11.405797  15.478261  1.173913  0.275362
# 9                 10  24.100000   7.933333  10.233333  0.600000  0.350000
# 10                11  24.547170   3.716981   5.716981  0.358491  0.094340
#
#     Strike_Rate
# 3     84.887439
# 2     76.648450
# 0     84.752910
# ...

# %%
col=['Runs','Balls','4s','6s']
for i in col:
    plt.boxplot(df[i])
    plt.title(i)
    plt.show()

# %%
df.isnull().sum()
# Out:
# Match_no            0
# Batting_Position    0
# Runs                0
# Balls               0
# 4s                  0
# 6s                  0
# Strike_Rate         6
# dtype: int64

# %%
df['Strike_Rate'].fillna(df['Strike_Rate'].mean(), inplace=True)

# %%
df.columns
# Out:
# Index(['Match_no', 'Batting_Position', 'Runs', 'Balls', '4s', '6s',
#        'Strike_Rate'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Match_no            0
# Batting_Position    0
# Runs                0
# Balls               0
# 4s                  0
# 6s                  0
# Strike_Rate         0
# dtype: int64

# %%
df.head()
# Out:
#    Match_no  Batting_Position  Runs  Balls  4s  6s  Strike_Rate
# 0         1                 1    33     35   4   1         94.3
# 1         1                 2    14     24   2   0         58.3
# 2         1                 3    77     86   4   1         89.5
# 3         1                 4    25     16   4   1        156.3
# 4         1                 5    11     17   1   0         64.7

# %%
df.tail()
# Out:
#      Match_no  Batting_Position  Runs  Balls  4s  6s  Strike_Rate
# 911        48                 2   137    120  15   4      114.167
# 912        48                 3    15     15   1   1      100.000
# 913        48                 4     4      9   1   0       44.444
# 914        48                 5    58    110   4   0       52.727
# 915        48                 6     2      1   0   0      200.000

# %%
sns.heatmap(df.corr(),annot=True,fmt='.2f')
plt.show()
